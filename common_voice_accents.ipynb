# %%
import pandas as pd

# %%
df = pd.read_csv('common_voice_accents.csv')

# %%
# df['accents'].unique()

# %%
label_dict = {'United States English,American Midwestern': 'usa', 'Filipino':'philippines',
       'United States English,wolof': 'usa', 'Australian English': 'australia',
       'United States English':'usa',
       'Southern African (South Africa, Zimbabwe, Namibia)': 'Southern African (South Africa, Zimbabwe, Namibia)',
       'England English': 'uk',
       'India and South Asia (India, Pakistan, Sri Lanka)': 'India and South Asia (India, Pakistan, Sri Lanka)',
       'United States English,Puerto Rican,Latin American English,Florida,New York,Long Island,Savannah, Georgia': 'usa',
       'Canadian English': 'canada', 'Hong Kong English': 'china',
       'Polish English,England English': 'poland', 'Scottish English': 'uk',
       'England English,Swedish': 'sweden', 'German English,"denglish"': 'germany',
       'United States English,Hong Kong English': 'china',
       'Upstate New York,United States English': 'usa', 'Singaporean English':'singapore',
       'Russian':'russia', 'Chichester':'uk', 'United States English,Gay':'usa',
       'Welsh English':'uk',
       'West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)':'West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)',
       'Non native': '', 'Deutsch English': 'germany',
       'I think mine accent is influenced by Indian Accent ,Yes Please. ,India and South Asia (India, Pakistan, Sri Lanka)':'India and South Asia (India, Pakistan, Sri Lanka)',
       'Irish English':'ireland', 'New Zealand English':'new zealand', 'Malaysian English':'malaysia',
       'Singaporean English,Thai English':'singapore',
       'England English,United States English':'uk',
       'United States English,Southern African (South Africa, Zimbabwe, Namibia)':'usa',
       'United States English,West Coast':'usa', 'Brooklyn ':'usa',
       'England English,Midlands English':'uk',
       'United States English,Southern New England English (Boston, Worcester, Lowell Area)':'usa',
       'English (Native Greek speaker)':'greece', 'United States English,Dutch':'usa',
       'Catalan':'Hispanic/Latino', 'indian':'India and South Asia (India, Pakistan, Sri Lanka)', 'Irish English,English':'ireland',
       'United States English,Midwestern':'usa',
       'United States English,Filipino':'usa',
       'United States English,Californian':'usa',
       'United States English,Mid Atlantica ,African American Vernacular ':'usa',
       'french accent':'france',
       'United States English,Born and lived in eastern VA for 8 years. Then lived in southern CA for 13 years.  Lived in MD, NC, WA, HI  for 1-3 years each.  Spent 30 years in Washington DC area and 17 years in Northern KY/Cincinnati OH area':'usa',
       'United States English,Northeast US':'usa',
       'I have none that I can tell.':'', 'Russian English':'russia',
       'Scottish English,Glaswegian ':'uk',
       'England English,Bedford English,Cambridge English':'uk',
       'United States English,India and South Asia (India, Pakistan, Sri Lanka)':'India and South Asia (India, Pakistan, Sri Lanka)',
       'United States English,United States-West Coast-Alaska,United States-Midwestern':'usa',
       'Neutral,indian,slow':'India and South Asia (India, Pakistan, Sri Lanka)', 'England English,Hong Kong English':'uk',
       'Argentinian English':'Hispanic/Latino', 'United States English,England English':'usa',
       'Canadian English,Welsh English':'canada', 'Filipino,Bisaya':'philippines',
       'french english':'france', 'Haitian Creole':'haiti', 'French':'france',
       "New Zealand English,I don't really speak english, just practicing":'new zealand',
       'United States English,Canadian English,Indo-Canadian English':'usa',
       'English (UK)':'uk', 'United States English,Slight Dutch accent':'usa',
       'United States English,Chicago ,Midwestern,Gen Z':'usa',
       'India and South Asia (India, Pakistan, Sri Lanka),United States English':'India and South Asia (India, Pakistan, Sri Lanka)',
       'United States English,Scandinavian':'usa', 'Western Europe':'',
       'United States English,Scottish English,Irish English,England English':'usa',
       'United States English,England English,Hong Kong English':'usa',
       'Southern African (South Africa, Zimbabwe, Namibia),Durban':'Southern African (South Africa, Zimbabwe, Namibia)',
       'United States English,English Second Language':'usa',
       'United States English,country':'usa',
       'slightly slurred due to age and alcohol consumption.':'',
       'Canadian English,United States English':'canada', 'South Australia':'australia',
       'northern cali':'usa', 'England English,Received Pronunciation':'uk',
       'Polish English':'poland',
       'I was born in England and have lived in Australia, Canada and France.':'uk',
       "Israeli's accent ":'israel',
       'England English,Southern African (South Africa, Zimbabwe, Namibia)':'uk',
       'United States English,Australian English':'usa', 'Second tongue':'',
       'Australian English,New Zealand English':'australia',
       'Italian,England English':'italy',
       'very slight Russian accent,Standard American English,Boston influence':'russia',
       'Southern Texas Accent,United States English':'usa', 'serbian':'serbia',
       'India and South Asia (India, Pakistan, Sri Lanka),Singaporean English':'India and South Asia (India, Pakistan, Sri Lanka)',
       'United States English,Midwest USA speech blended with South Texas USA speech':'usa',
       'New York City':'usa', 'Australian English,General Australian':'usa',
       'Nigerian ':'nigeria', 'Swedish English':'sweden', 'Finnish':'finland', 'Non-native':'',
       'United States English,United States English. people say I sound like a surffer dude.':'usa',
       'Not bad':'', 'United States English,East Texas,Texan':'usa',
       'United States English,Northern,Urban':'usa',
       'New Zealand English,United States English':'new zealand',
       'Singaporean English,England English':'singapore', 'German English':'germany', 'Chinese':'china',
       'England English,Middle-class London English accent with a very slight west-country twang':'uk',
       'English County Durham':'uk', 'Japanese English':'japan',
       'Выраженный украинский акцент':'ukraine',
       'South Atlantic (Falkland Islands, Saint Helena)':'',
       'United States English,southern United States':'usa',
       'England English,Educated,non regional':'uk',
       'United States English,Northeastern,Rhode Island,Massachusetts':'usa',
       'Canadian English,Pacific Northwest English':'canada',
       'United States English,plain,southern draw,west coast surfer dude':'usa',
       'India and South Asia (India, Pakistan, Sri Lanka),Basic':'India and South Asia (India, Pakistan, Sri Lanka)',
       'Hunglish':'hungary', 'East London ':'uk', 'United States English,Colombia':'usa',
       'Non native speaker from France':'france', "A'lo":'', 'Hispanic/Latino':'Hispanic/Latino',
       'United States English,Variable':'usa',
       'United States English,Silicon Valley Native':'usa',
       'United States English,Midwest US... With some Canadian slang. ':'usa',
       'Brazilian':'brazil', 'United States English,Foreigner English':'usa',
       'England English with a touch of Canadian':'usa',
       'United States English,California':'usa',
       'United States English,Canadian English':'usa', 'Slavic':'slovakia',
       'Northern Irish':'ireland', 'Canadian English,Swedish English':'canada',
       'United States English,England English,India and South Asia (India, Pakistan, Sri Lanka)':'usa',
       'New Jerseyan':'usa', 'nigeria english':'nigeria',
       'Hong Kong English,Scottish English':'china',
       'Mild Northern England English':'uk', 'England non-native':'uk',
       'New Zealand English,England English':'new zealand',
       'United States English,Kenyan English':'usa',
       'European English,French,Romanian':'france',
       'United States English,Southern Appalachian English,Southern United States English':'usa',
       'United States English,United States English Pacific Northwest':'usa',
       'United States English,southern, formal, sultry':'usa',
       "England English,Porto des dels 3 anys aprenent anglès a l'escola i actualment m'estic preparant per a l'examen del B2.":'uk',
       'British':'uk',
       'India and South Asia (India, Pakistan, Sri Lanka),England English':'India and South Asia (India, Pakistan, Sri Lanka)',
       'England English,yorkshire':'uk',
       'United States English,i have some pronunciation issues because of oral surgery and a hidden southern accent':'usa',
       'Colombian Accent':'Hispanic/Latino', 'German':'germany',
       'United States English,little bit classy little bit sassy and add some city.....thats me':'usa',
       'United States English,Minnesotan':'usa',
       'India and South Asia (India, Pakistan, Sri Lanka),England English,United States English':'India and South Asia (India, Pakistan, Sri Lanka)',
       'Scottish English,Scottish':'uk',
       'United States English combined with European English':'usa',
       'Norwegian':'norway',
       'West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad),Patois':'West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)',
       'English with Swiss german accent':'switzerland', 'East Indian':'India and South Asia (India, Pakistan, Sri Lanka)',
       'United States English,pin/pen merger':'usa', 'Hispanic':'Hispanic/Latino', 'Latino':'Hispanic/Latino',
       'England English,London English':'uk',
       'United States English,midwestern US':'usa', 'Kenyan ,East African':'kenya',
       'Russian,East Ukrainian ':'russia', 'Spanish bilingual':'Hispanic/Latino', 'Czech accent':'czech republic',
       'Southern African (South Africa, Zimbabwe, Namibia),England English':'Southern African (South Africa, Zimbabwe, Namibia)',
       'U.K. English': 'uk', 'United States English,California English':'uk',
       'English north of England ':'uk',
       'German English,I am German and speak English as learned at school':'germany',
       'Afrikaans English':'Southern African (South Africa, Zimbabwe, Namibia)', 'Bangladeshi,Bangladesh English':'bangladesh',
       'Filipino,United States English':'philippines',
       'United States English,Midwest United States':'usa', 'mexican accent':'Hispanic/Latino',
       'West Indian':'India and South Asia (India, Pakistan, Sri Lanka)',
       'United States English,Slight Latino accent, immigrant':'usa',
       'Liverpudlian English':'uk',
       'International English,United States English,Australian English':'usa',
       'Transnational englishes blend':'', 'Swiss English':'switzerland', 'California':'usa',
       'Dutch,European,Adjustable':'netherlands', 'Latin America,United States English':'Hispanic/Latino',
       'polish accent':'poland',
       'United States English,Australian English,England English,New Zealand English,India and South Asia (India, Pakistan, Sri Lanka),international,Slovak':'usa',
       'Greek':'greece', 'Brazillian Accent':'brazil',
       'England English,East Anglian English':'uk', 'North European English':'',
       'Georgian English':'usa', 'United States English,Mix of voices':'usa',
       'United States English,Mid-atlantic':'usa',
       "European,eastern europe,pronounced r's,heavy consonants ":'',
       'India and South Asia (India, Pakistan, Sri Lanka),Indian with a tinge of an RP accent':'India and South Asia (India, Pakistan, Sri Lanka)',
       'United States English,Pittsburgh PA':'usa',
       'slighty Southern affected by decades in the Midwest, 4 years in Spain and Germany, speak some German, Spanish, Polish. Have lived in nine states.':'usa',
       'mostly American with some British and Australian inflections':'usa',
       'Non-native,German Accent':'germany', 'Kenyan English':'kenya',
       'United States English,Midwestern United States English':'usa',
       'Chinese English':'china', 'German Accent':'germany', 'A Savage Texas Gentleman ':'usa',
       'Latin American accent':'Hispanic/Latino', 'Eastern European English':'',
       'Australian English,Sydney - middle eastern seaboard Australian':'australia',
       'United States English,Central American ':'usa',
       'United States English,Chicano English,"Valley Girl" English':'usa',
       'United States English,Israeli accent':'usa', 'European English':'',
       'England English,Southern England':'uk', 'South African English':'Southern African (South Africa, Zimbabwe, Namibia)',
       'Kenyan ':'kenya', 'American South East Georgia Dialect':'usa',
       'A variety of Texan English with some German influence that has undergone the cot-caught merger':'usa',
       'United States English,Canadian English,slight Brooklyn Accent':'usa',
       'United States English,midwest':'usa', 'Caribbean Canadian ':'canada',
       'Generic European':'', 'Australian English,England English,Japanese':'australia',
       'Slavic,Russian':'slovakia', 'fluent,ESL,European':'', 'West African ':'',
       'England English,Lancashire, England ':'uk',
       'United States English,United States, west coast English ':'usa',
       'United States English,Hmong-American':'usa',
       'New Zealand English,Australian English,England English':'new zealand',
       'Singaporean English,Malaysian English':'singapore',
       'England English,Scottish English':'uk', 'England English,Norwegian':'uk',
       'Kiwi':'new zealand', 'United States English,Chicago ':'usa',
       'United States English,American Midwest':'usa',
       'Canadian English,Irish English':'canada',
       'bangladesh,India and South Asia (India, Pakistan, Sri Lanka)':'bangladesh',
       'polish':'poland', 'Australian English,England English':'australia',
       'United States English,Cool':'usa',
       'Australian English,Educated Australian Accent':'australia',
       'serbian,United States English':'serbia',
       'United States English,Asian-American English':'usa',
       'England English,south German / Swiss accent':'uk',
       'United States English,Okie':'usa',
       'India and South Asia (India, Pakistan, Sri Lanka),Canadian English':'India and South Asia (India, Pakistan, Sri Lanka)',
       'Mix of american and british accent':'usa',
       'United States English,new england/east coast':'usa',
       'Kenyan English accent': 'kenya', 'Swedish accent':'kenya', 'Nigerian English':'nigeria',
       'West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad),England English,Scottish English,United States English':'West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)',
       'United States English,Spoke Chinese when little,90% Pennsylvanian accent, 10% Chinese accent':'usa',
       'Israeli':'israel', 'United States English,Upper Midwestern':'usa',
       'England English,United States English,English with Polish accent,Slavic English':'uk',
       'Thai':'thailand', 'England English,South London and Essex':'uk',
       'United States English,Mid-west United States English':'usa',
       'Latin English':'Hispanic/Latino', 'British accent':'uk', 'With heavy Cantonese accent':'china',
       '2nd Language ':'', 'Southern drawl':'usa', 'Kazakhstan English':'kazakhstan',
       'Transatlantic English,United States English,England English':'usa',
       'minor french accent':'france',
       'United States English,England English,ohio':'usa', 'Dutch English':'netherlands',
       'Eastern European,Romanian':'romanian', 'england,london,academic':'uk',
       'french accent,French mid level accent':'france', 'England English,British':'uk',
       'Indonesian':'indonesia',
       'India and South Asia (India, Pakistan, Sri Lanka),International Indian Accent':'India and South Asia (India, Pakistan, Sri Lanka)',
       'Javanese,Indonesian English,Malaysian English':'japan',
       'little latino,United States English,second language':'Hispanic/Latino',
       'Mid-atlantic,England English,United States English':'uk',
       'Midatlantic,England English':'uk', 'Malaysian English,England English':'malaysia',
       'United States English,Midwestern States (Michigan)':'usa',
       'Israeli English':'israel', 'Ukrainian':'ukraine',
       'United States English,Some time spent in Scotland, mostly affecting inflection, I think':'usa',
       'United States English,Californian Accent':'usa',
       'Canadian English,United States English,England English':'canada',
       'Northern Irish,Norwegian,yorkshire':'ireland', 'Austrian':'austria',
       'Midwestern US English (United States),United States English':'usa',
       'Italian':'italy', 'Bulgarian':'bulgaria', 'German English,England English':'germany',
       'United States English,South Texas,Slightly effeminate,Conversational':'usa',
       'South German accent,Alemannic German Accent,German,south-west German':'germany',
       'India and South Asia (India, Pakistan, Sri Lanka),try to maintain originality ':'India and South Asia (India, Pakistan, Sri Lanka)',
       'England English,Northern English':'uk',
       'England English,India and South Asia (India, Pakistan, Sri Lanka),Northern English':'uk',
       'Slavic,East European,polish':'slovakia', 'United States English,Slight lisp':'usa',
       'Spanish,Foreign,Non-native':'Hispanic/Latino', 'Ontario,Canadian English':'canada',
       'United States English,Pacific Northwest ':'usa',
       'England English,Welsh English':'uk',
       'England English,southern english,sussex':'uk',
       'European,German,Foreign,Non-native':'germany', 'Bangladeshi English':'bangladesh',
       'Dutch':'netherlands', 'Southern Californian,United States English':'usa',
       'Northern Irish,culchie':'ireland',
       'England English,New Zealand English,Welsh English,Australian English,United States English,Mixed-Accent English':'uk',
       'Mid-Atlantic United States English,Philadelphia, Pennsylvania, United States English,United States English,Philadelphia Style United States English':'usa',
       'United States English,CARIBBEAN AND BRITISH MIXED WITH SOME NEW YORK ACCENTS':'usa',
       'Slavic,polish':'slovakia', 'England English,South London':'uk',
       'Northumbrian British English':'uk', 'England English,Canadian English':'uk',
       'England English,Northern England':'uk',
       'United States English,Southwestern United States English':'usa',
       'Unite States Midwest,United States English':'usa', 'East African Khoja':'',
       'Nepali':'nepal', 'United States English,Midwestern,Minnesotan':'usa',
       'United States English,southern United States,New Orleans dialect':'usa',
       'Academic southern English,England English':'uk',
       'southern United States,United States English':'usa',
       'United States English,Midwestern,Low,Demure':'usa',
       'Transatlantic English,United States English':'usa',
       'England English,New Zealand English':'uk',
       'Liverpool English,Lancashire English,England English':'uk',
       'German English,Non native speaker':'germany'}

# %%
df['accents_cleaned']=df['accents'].map(label_dict)

# %%
labeled_df = df[df['accents_cleaned']!='']

# %%
labeled_df.accents_cleaned.value_counts()
# Out:
# usa                                                              366571
# uk                                                               144705
# India and South Asia (India, Pakistan, Sri Lanka)                 79164
# canada                                                            58504
# australia                                                         44051
# germany                                                           38350
# ireland                                                           17056
# new zealand                                                       12287
# Southern African (South Africa, Zimbabwe, Namibia)                 7658
# philippines                                                        4383
# china                                                              3411
# singapore                                                          2780
# malaysia                                                           1464
# ...

# %%
labeled_df.to_csv("common_voice_accents.csv")

# %%
# others = ["ukraine","poland","japan","indonesia","kazakhstan","romanian","serbia","brazil","switzerland","greece","sweden","czech republic","norway","hungary","finland","haiti"]

# %%
# labeled_df.loc[labeled_df.accents_cleaned.isin(others), 'accents_cleaned'] = 'other'

# %%
labeled_df.accents_cleaned.value_counts()
# Out:
# usa                                                              366571
# uk                                                               144705
# India and South Asia (India, Pakistan, Sri Lanka)                 79164
# canada                                                            58504
# australia                                                         44051
# germany                                                           38350
# ireland                                                           17056
# new zealand                                                       12287
# Southern African (South Africa, Zimbabwe, Namibia)                 7658
# philippines                                                        4383
# china                                                              3411
# singapore                                                          2780
# malaysia                                                           1464
# ...

# %%
vc = labeled_df.accents_cleaned.value_counts().to_dict()

# %%
for k,v in vc.items():
    print("{} \t{:.04f}%".format(k, (v/labeled_df.size)*100))
# Out:
# usa 	3.3428%
# uk 	1.3196%
# India and South Asia (India, Pakistan, Sri Lanka) 	0.7219%
# canada 	0.5335%
# australia 	0.4017%
# germany 	0.3497%
# ireland 	0.1555%
# new zealand 	0.1120%
# Southern African (South Africa, Zimbabwe, Namibia) 	0.0698%
# philippines 	0.0400%
# china 	0.0311%
# singapore 	0.0254%
# malaysia 	0.0134%
# West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad) 	0.0058%
# other 	0.0028%
# slovakia 	0.0027%
# nepal 	0.0027%
# netherlands 	0.0022%
# Hispanic/Latino 	0.0019%
# austria 	0.0012%
# nigeria 	0.0011%
# france 	0.0010%
# bangladesh 	0.0010%
# thailand 	0.0010%
# bulgaria 	0.0006%
# israel 	0.0006%
# italy 	0.0006%
# russia 	0.0006%
# kenya 	0.0006%

# %%
labeled_df['probs'] = labeled_df['accents_cleaned'].map(vc)
# Out:
# /var/folders/26/kzg0fcnn1qn7jnrdq0w2c8680000gn/T/ipykernel_1831/380279582.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   labeled_df['probs'] = labeled_df['accents_cleaned'].map(vc)

# %%
labeled_df['probs'] /= labeled_df.size
# Out:
# /var/folders/26/kzg0fcnn1qn7jnrdq0w2c8680000gn/T/ipykernel_1831/1103547257.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   labeled_df['probs'] /= labeled_df.size

# %%
labeled_df.head(50)
# Out:
#     Unnamed: 0                                          client_id  \
# 0           31  01b8cbbac0a4164a98fb42f0c9de764fc4b5547de07b47...
# 1           69  0365b018a15ab96510f1368f4910554f97f6c278320e78...
# 2           87  0446e65032f30acdda12c87fef9d1de14d34946a4d2430...
# 3          131  0621ad6390e651ff1e39b23f74e8d624bd8ba0957d6a19...
# 4          136  06546553aed17027b4e638d4afb56f39b216026088cf40...
# 5          170  07df65e4465dbe1499668503f5f4446042b86e0403ede1...
# 6          173  07eb9e52f1b3194e512d94b8871d770ae74455ddc6f6b6...
# 7          181  0823a0f65b1bd20d50350b79fbe1c8304f7078bb79d0ac...
# 8          196  08dd401a7d849c95af91ac271725bb453f996be2e8cc38...
# 9          215  09aa82e1d326297ee6426370a6f868bc9fb60bbce3e4f0...
# 10         235  0a8f4c13d8f2deb5abf8d10975a2eba3406488f162b4bc...
# 11         251  0b2e75a7b585ed41f0f93144f2cfbc91681cc9bc54276f...
# 12         280  0c5c270a2e7a64f9d446f593d2258f335a5fbd764536e8...
# ...

# %%
# df.head(50)

# %%
# cv_df = pd.read_csv('CommonVoice_validated.tsv', sep='\t')

# %%
# print("orignal number of rows",len(cv_df.index))
# Out:
# orignal number of rows 1689234

# %%
# accent_df = cv_df[cv_df['accents'].notna()]

# %%
# print("number of rows with accents", len(accent_df.index))
# Out:
# number of rows with accents 907238

# %%
# accent_no_downvote = accent_df[accent_df['down_votes']==0]

# %%
# print("number of rows with accents and no down votes", len(accent_no_downvote.index))
# Out:
# number of rows with accents and no down votes 783951

# %%
# accent_no_downvote.head(50)
# Out:
#                                              client_id  \
# 31   01b8cbbac0a4164a98fb42f0c9de764fc4b5547de07b47...
# 69   0365b018a15ab96510f1368f4910554f97f6c278320e78...
# 87   0446e65032f30acdda12c87fef9d1de14d34946a4d2430...
# 131  0621ad6390e651ff1e39b23f74e8d624bd8ba0957d6a19...
# 136  06546553aed17027b4e638d4afb56f39b216026088cf40...
# 170  07df65e4465dbe1499668503f5f4446042b86e0403ede1...
# 173  07eb9e52f1b3194e512d94b8871d770ae74455ddc6f6b6...
# 181  0823a0f65b1bd20d50350b79fbe1c8304f7078bb79d0ac...
# 196  08dd401a7d849c95af91ac271725bb453f996be2e8cc38...
# 215  09aa82e1d326297ee6426370a6f868bc9fb60bbce3e4f0...
# 235  0a8f4c13d8f2deb5abf8d10975a2eba3406488f162b4bc...
# 251  0b2e75a7b585ed41f0f93144f2cfbc91681cc9bc54276f...
# 280  0c5c270a2e7a64f9d446f593d2258f335a5fbd764536e8...
# 304  0d9fa7ab4c5ad47ecbcdf800f05c3cee78ec69e8f6aba1...
# 305  0da878db8a36dd209ad09c02f0e3452640b0383f3e6e05...
# 343  0f71516b09705a899f26f244185d7d231800de5769c13e...
# ...

# %%
accent_no_downvote.accents.value_counts()
# Out:
# United States English                                                    360588
# England English                                                          125251
# India and South Asia (India, Pakistan, Sri Lanka)                         78865
# Canadian English                                                          58312
# Australian English                                                        43989
#                                                                           ...
# Scottish English,Glaswegian                                                   1
# England English,Bedford English,Cambridge English                             1
# I was born in England and have lived in Australia, Canada and France.         1
# English (UK)                                                                  1
# United States English,American Midwestern                                     1
# Name: accents, Length: 337, dtype: int64

# %%
"""
['south africa', 'ivory coast', 'ghana', 'kosovo', 'albania',
       'morocco', 'ethiopia', 'saudi arabia', 'egypt', 'lebanon', 'qatar',
       'tunisia', 'iraq', 'jordan', 'kuwait', 'syria',
       'united arab emirates', 'israel (occupied territory)', 'israel',
       'usa', 'algeria', 'yemen', 'bahrain', 'libya', 'oman', 'uk',
       'sudan', 'armenia', 'iran', 'republic of georgia', 'russia',
       'azerbaijan', 'cameroon', 'guinea', 'china', 'mali', 'senegal',
       'spain', 'germany', 'belarus', 'bangladesh', 'india', 'zambia',
       'bosnia and herzegovina', 'bulgaria', 'myanmar',
       'northern mariana islands', 'chile', 'philippines', 'malawi',
       'croatia', 'czech republic', 'denmark', 'afghanistan',
       'netherlands', 'belgium', 'south korea', 'nigeria', 'canada',
       'us virgin islands', 'malaysia', 'australia', 'ireland', 'jamaica',
       'guyana', 'fiji', 'antigua and barbuda', 'panama', 'barbados',
       'new zealand', 'singapore', 'isle of man', 'belize', 'bolivia',
       'trinidad', 'liberia', 'switzerland', 'virginia', 'the bahamas',
       'italy', 'papua new guinea', 'pakistan', 'estonia',
       'equatorial guinea', 'faroe islands', 'timor-leste', 'finland',
       'france', 'haiti', 'democratic republic of congo', 'andorra',
       'portugal', 'gabon', 'burkina faso', 'martinique', 'uganda',
       'honduras', 'austria', 'liechtenstein', 'greece', 'cyprus',
       'kenya', 'taiwan', 'niger', 'laos', 'hungary', 'romania',
       'iceland', 'togo', 'indonesia', 'japan', 'botswana', 'kazakhstan',
       'cambodia', 'angola', 'kyrgyzstan', 'tanzania', 'sierra leone',
       'federated states of micronesia', nan, 'latvia', 'lithuania',
       'luxembourg', 'macedonia', 'madagascar', 'malta', 'mauritius',
       'nicaragua', 'mongolia', 'namibia', 'nepal', 'norway', 'curacao',
       'poland', 'brazil', 'mexico', 'peru', 'moldova', 'romanian',
       'ukraine', 'burundi', 'uzbekistan', 'rwanda', 'solomon islands',
       'chad', 'bosnia', 'serbia', 'montenegro', 'yugoslavia', 'lesotho',
       'zimbabwe', 'sicily', 'sri lanka', 'slovak republic', 'slovakia',
       'slovenia', 'somalia', 'venezuela', 'el salvador', 'colombia',
       'cuba', 'ecuador', 'puerto rico', 'guatemala', 'uruguay',
       'argentina', 'costa rica', 'dominican republic', 'sweden',
       'tajikistan', 'thailand', 'tibet', 'eritrea', 'turkey',
       'turkmenistan', 'vietnam', 'benin']
"""

# %%
accent_no_downvote['accents'].unique().size
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 accent_no_downvote['accents'].unique().size
#
# NameError: name 'accent_no_downvote' is not defined

# %%
import altair as alt

# %%
random5000 = accent_no_downvote.sample(n=5000)

# %%
alt.Chart(random5000).mark_bar().encode(
    alt.X('accents'),
    alt.Y('count()'),
    alt.Color('age')
)
# Out:
# alt.Chart(...)

# %%
accent_no_downvote.to_csv("commonvoice_accents.csv")
